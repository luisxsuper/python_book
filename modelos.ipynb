# %%
print("Hola pes xd "*6)
# Out:
# Hola pes xd Hola pes xd Hola pes xd Hola pes xd Hola pes xd Hola pes xd

# %%
23+6
# Out:
# 29

# %%
# The code below can be passed over, as it is currently not important, plus it
# uses advanced topics we have not covered yet. LOOK AT PICTURE, MICHAEL!
# %matplotlib inline
from IPython.core.pylabtools import figsize
import numpy as np
from matplotlib import pyplot as plt
figsize(11, 9)

import scipy.stats as stats

dist = stats.beta
n_trials = [0, 1, 2, 3, 4, 5, 8, 15, 50, 500]
data = stats.bernoulli.rvs(0.5, size=n_trials[-1])
x = np.linspace(0, 1, 100)

# For the already prepared, I'm using Binomial's conj. prior.
for k, N in enumerate(n_trials):
    sx = plt.subplot(len(n_trials) / 2, 2, k + 1)
    plt.xlabel("$p$, probability of heads") \
        if k in [0, len(n_trials) - 1] else None
    plt.setp(sx.get_yticklabels(), visible=False)
    heads = data[:N].sum()
    y = dist.pdf(x, 1 + heads, 1 + N - heads)
    plt.plot(x, y, label="observe %d tosses,\n %d heads" % (N, heads))
    plt.fill_between(x, 0, y, color="#348ABD", alpha=0.4)
    plt.vlines(0.5, 0, 4, color="k", linestyles="--", lw=1)

    leg = plt.legend()
    leg.get_frame().set_alpha(0.4)
    plt.autoscale(tight=True)


plt.suptitle("Bayesian updating of posterior probabilities",
             y=1.02,
             fontsize=14)

plt.tight_layout()

# %%
from pandas import *
#import pandas as pd
from matplotlib.pyplot import *
 #%%
df = read_csv("ingresos_gastos.csv")
print(df)
scatter(df["ingresos"],df["gastos"])
xlabel("Ingresos")
ylabel("Gastos")
plt.show()
#plt.savefig("notas.png")
sum(df["ingresos"])/len(df)
#%
import matplotlib.pyplot as plt
import scipy.stats as st
x = np.linspace(0.0, 1.0)
plt.plot(x, st.norm.pdf(x, -1.0, np.sqrt(0.5)))
plt.show()
# Out:
#     id  ingresos  gastos
# 0    1      1000     800
# 1    2      1100     885
# 2    3      1100     880
# 3    4      1200    1000
# 4    5      1400    1000
# 5    6       900     750
# 6    7       600     550
# 7    8      2000    1200
# 8    9      1200    1000
# 9   10      1250    1000
# 10  11      3000    2400
# 11  12      2200    1700
# 12  13      1700    1300
# 13  14      1650    1220
# 14  15      1825    1500
# 15  16      1435    1200
# 16  17       980     800
# 17  18      1050     800
# 18  19      2105    1680
# 19  20      1280    1020
# 20  21      1590    1272
# 21  22      1300    1040
# 22  23      1200    1000
# 23  24      1110     890
# 24  25       850     680

# %% [markdown]
# $Esta \times Ecuación = \frac{Es}{En \cdot la \cdot misma \cdot línea}$

# %%
# uses advanced topics we have not covered yet. LOOK AT PICTURE, MICHAEL!
#%matplotlib inline

# %% [markdown]
# $\beta_1= \frac{(sumxy-n*promx*promy)}{(sumx2-n*promx^2)}$

# %%
from pandas import *
from numpy import * 
#import pandas as pd
from matplotlib.pyplot import *
 #%%
df = read_csv("see.csv", sep =";")
print(df);print()
x = (df["Xi"]); y = df["Yi"]
n = len(x) 
sumx = sum(x); sumy = sum(y)
sumx2 = sum(x**2); sumy2 = sum(y**2)
sumxy = sum(x*y)
promx = mean(x); promy = mean(y)

B1 = (sumxy - n * promx * promy)/(sumx2 - n * promx**2) ; print ("B1 = ",B1)
B0 = promy - B1 * promx; print("B0 = ",B0)

plot(x, y, 'o', label = 'Datos')
#plot(x, m*x+b, label = 'Ajuste')
xlabel("x"); ylabel("y")
title("Regresion Lineal")
grid();
show()
#scatter(df["Yi"],df["Xi"])
#xlabel("x")
#ylabel("y")
#show()
rxy = (sumxy - sumx*sumy/n) / sqrt((sumx2 - sumx**2/n) * (sumy2 - sumy**2/n))
print("Correlacion = ",rxy)
print
# Out:
#    Yi    Xi
# 0  45  1.50
# 1  65  1.65
# 2  55  1.70
# 3  62  1.80
# 4  68  1.85
# 5  56  1.60
# 6  54  1.59
#
# B1 =  52.42290748898704
# B0 =  -29.689112649465507
# Correlacion =  0.8292704500605806
